// %% [markdown]
// ### SOAL UAS
// 1. Jawablah soal - soal dibawah ini pada baris yang sudah disediakan.
// 2. Jawaban diunggah pada folder github masing - masing mahasiswa dijadikan satu dengan tugas - tugas sesudah UTS
// 3. Dikumpulkan paling lambat 7 Juli 2020 Jam 24.00

// %%
Berikut ini adalah contoh pengkodean lambda : 
(Jika ada kekeliruan dalam syntax silahkan dibetulkan)

// %%
//Implementasi
ContohLambda TestLambda = new ContohLambda()
    publik clas ContohLambda{

    public static void main(){
      ContohLambda obj = new ContohLambda();

      //dengan type declaration tanpa kurung kurawal
      OperasiPerhitungan penjumlahan = (int a, int b) -> a + b;

       //dengan return statement dan dengan kurung kurawal
      OperasiPerhitungan penjumlahan2 = (int a, int b) -> { return a + b; };



      system.out.println("10 + 5 = " + obj.operate(10, 5, penjumlahan));
      system.out.println("10 - 5 = " + obj.operate(10, 5, penjumlahan2));

      //dengan parenthesis
      msgService greetService1 = message -> system.out.println("Hello " + message);

      //tanpa parenthesis
      msgService greetService2 = (message) -> System.out.println("msg. " + message);

      greetService1.sayMessage("Helloo");
      greetService2.sayMessage("Anonim..");
   }

   private interface OperasiPerhitungan{
      int operation(int a, int b);
   }

   private interface msgService{
      void sayMessage(String message);
   }

   private int operate(int a, int b, OperasiPerhitungan op){
      return op.operation(a, b);
   }

}

// %% [markdown]
// ### [Soal 1]
//
// Jelaskan mengenai ekspresi lambda dalam pemrograman java? Apa saja yang menjadi karakteristik dari ekspresi tersebut?
// *(nilai 30)*

// %% [markdown]
// jawab :ContohLambda TestLambda = new ContohLambda()
//     publik clas ContohLambda{
//
//     public static void main(){
//       ContohLambda obj = new ContohLambda();
//
//       //dengan type declaration tanpa kurung kurawal
//       OperasiPerhitungan penjumlahan = (int a, int b) -> a + b;
//
//        //dengan return statement dan dengan kurung kurawal
//       OperasiPerhitungan penjumlahan2 = (int a, int b) -> { return a + b; };
//
//
//
//       system.out.println("10 + 5 = " + obj.operate(10, 5, penjumlahan));
//       system.out.println("10 - 5 = " + obj.operate(10, 5, penjumlahan2));
//
//       //dengan parenthesis
//       msgService greetService1 = message -> system.out.println("Hello " + message);
//
//       //tanpa parenthesis
//       msgService greetService2 = (message) -> System.out.println("msg. " + message);
//
//       greetService1.sayMessage("Helloo");
//       greetService2.sayMessage("Anonim..");
//
//       }
//
//    private interface OperasiPerhitungan{
//       int operation(int a, int b);
//    }
//
//    private interface msgService{
//       void sayMessage(String message);
//    }
//
//    private int operate(int a, int b, OperasiPerhitungan op){
//       return op.operation(a, b);
//    }
//
// }

// %% [markdown]
// ### [Soal 2]
//
// Implementasikan ekspresi lambda dari kasus UTS bangun datar anda *(nilai 70)*

// %%
//Implementasi Kode Jawaban :
#include<iostream.h>
#include<conio.h>

void bola()
{
  int r,volume;
  cout<<"masukan nilai jari-jari : ";
  cin>>r;
  cout<<"volume bola = "<<4/3*3.14*r*r*r<<endl;
}

int main() {

    bola();
    return 0;
}

Program classnya:

#include <iostream.h>
#include <conio.h>

class volume {
friend istream& operator >> (istream&, volume&);
friend ostream& operator << (ostream&, const volume&);

public:
volume();
void hitung_volumenya(){ volume = 4/3*3.14*r*r*r;}

private:
    int r;
    float volume;
};

volume::volume(){
cout << "Program mencari volume bola \n" << endl;
}
istream& operator >>(istream& cin, volume& masukan){
   cout << "Masukkan jari-jari : ";   cin >> masukan.r;
   cout<<endl;

return cin;
}
ostream& operator << (ostream& out, const volume& keluaran)
{
  out<< " Nilai jari- jari : " <<keluaran.r<<endl;
  out<< " volume bola = "<<keluaran.volume<<endl;

return out;
}

void main(){
  volume bola;
  cin>>bola;
  bola.hitung_volumenya();
  cout<<bola;

  getch();

}


Teman-teman juga bisa mendemokannya ke jeliot ,, check it out ....
Demo ke jeliot :
Fungsi Menghitung Volume Bola
import jeliot.io.*;

public class volume {
public static void main()
{
     int r ;
     float volume;
     System.out.print("Masukan jari-jari : ");
     r = Input.readInt();
    
     volume = (float)4/3*(float)3.14*r*r*r;
     System.out.print("Volume bola = ");
     System.out.print(volume);
 }
}

// %% [markdown]
// Penjelasan Program
// Penjelasan:
// Program di atas adalah program untuk menghitung volume bola dengan menggunakan fungsi. Program mana yang akan memanggil fungsionalitas. Dalam program ini menggunakan variabel r dan volume. Program akan melakukan proses penghitungan dengan formula yang telah ditentukan. Setelah pengguna memasukkan nilai r maka volume bola akan muncul.
